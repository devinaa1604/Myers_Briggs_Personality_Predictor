# %% [markdown]
# # INITIAL IMPORTS

# %%
#Basics
import pandas as pd
import numpy as np
from pathlib import Path
import os
import seaborn as sns
import nltk
import re
import matplotlib.pyplot as plt

# %matplotlib inline

#SKLearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score

#Metrics
import sklearn
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score, multilabel_confusion_matrix, confusion_matrix
from sklearn.metrics import classification_report

#Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb

# preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest
from sklearn.compose import ColumnTransformer

# class imbalance
from imblearn.pipeline import make_pipeline as imb_make_pipeline
from imblearn.under_sampling import RandomUnderSampler

# algorithms/models
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import LinearSVC, SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# model evaluation
from imblearn.metrics import classification_report_imbalanced
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score

# performance check
import time
import warnings
warnings.filterwarnings("ignore")

# sparse to dense
from sklearn.base import TransformerMixin


class DenseTransformer(TransformerMixin):
    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X, y=None, **fit_params):
        return X.todense()

# %% [markdown]
# # READ DATA

# %%
df_path = Path("/Users/devinaamangal/Project-2/Final_ipynb/Resources/df_train.csv")
df_train = pd.read_csv(df_path, index_col=["type"])
df_train.head()
# Out:
#                                                   posts  words_per_comment  \
# type
# INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...              11.12
# ENTP  'I'm finding the lack of me in these posts ver...              23.40
# INTP  'Good one  _____   https://www.youtube.com/wat...              16.72
# INTJ  'Dear INTP,   I enjoyed our conversation the o...              21.28
# ENTJ  'You're fired.|||That's another silly misconce...              19.34
#
#       variance_of_word_counts  http_per_comment  img_per_comment  \
# type
# INFJ                 135.2900              0.48             0.12
# ENTP                 187.4756              0.20             0.02
# INTP                 180.6900              0.10             0.00
# INTJ                 181.8324              0.04             0.00
# ENTJ                 196.4576              0.12             0.04
#
#       qm_per_comment  excl_per_comment  ellipsis_per_comment  E  I  ...  T  P  \
# type                                                                ...
# INFJ            0.36              0.06                  0.30  0  1  ...  0  0
# ENTP            0.10              0.00                  0.38  1  0  ...  1  1
# INTP            0.24              0.08                  0.26  0  1  ...  1  1
# INTJ            0.22              0.06                  0.52  0  1  ...  1  0
# ENTJ            0.20              0.02                  0.42  1  0  ...  1  0
#
#       J  nouns_per_comment  adjs_per_comment  verbs_per_comment  \
# type
# INFJ  1               5.18              1.62               1.72
# ENTP  0               3.98              2.12               4.68
# INTP  0               2.70              1.68               3.10
# INTJ  1               3.28              1.80               4.14
# ENTJ  1               3.58              1.80               4.42
#
#       prepositions_per_comment  interjections_per_comment  \
# type
# INFJ                      0.54                       0.00
# ENTP                      2.72                       0.04
# INTP                      1.32                       0.08
# INTJ                      1.88                       0.04
# ENTJ                      1.78                       0.06
#
#       determiners_per_comment  sentiment
# type
# INFJ                     1.06   0.166656
# ENTP                     1.84   0.104312
# INTP                     1.10   0.145745
# INTJ                     1.86   0.131263
# ENTJ                     1.60   0.075231
#
# [5 rows x 23 columns]

# %%
combined_path = Path("/Users/devinaamangal/Project-2/Final_ipynb/Resources/df_combined.csv")
df_combined = pd.read_csv(combined_path, index_col=["type"])
df_combined.head()
# Out:
#       is_Extrovert  is_Sensing  is_Thinking  is_Judging  \
# type
# INFJ             0           0            0           1
# ENTP             1           0            1           0
# INTP             0           0            1           0
# INTJ             0           0            1           1
# ENTJ             1           0            1           1
#
#                                                    text  Compound  Negative  \
# type
# INFJ  moment sportscenter top ten play prank life ch...    0.9924     0.132
# ENTP  finding lack post alarming sex boring position...    0.9987     0.119
# INTP  good one course say know blessing curse absolu...    0.9985     0.116
# INTJ  dear enjoyed conversation day esoteric gabbing...    0.9985     0.087
# ENTJ  fired another silly misconception approaching ...    0.9930     0.186
#
#       Neutral  Positive
# type
# INFJ    0.597     0.271
# ENTP    0.598     0.284
# INTP    0.581     0.303
# INTJ    0.661     0.252
# ENTJ    0.538     0.276

# %%
combined_df = pd.concat([df_train,df_combined], axis='columns')
combined_df = combined_df.reset_index()
combined_df = combined_df[combined_df["text"].isnull()==False]
combined_df.head()
# Out:
#    type                                              posts  words_per_comment  \
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...              11.12
# 1  ENTP  'I'm finding the lack of me in these posts ver...              23.40
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...              16.72
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...              21.28
# 4  ENTJ  'You're fired.|||That's another silly misconce...              19.34
#
#    variance_of_word_counts  http_per_comment  img_per_comment  qm_per_comment  \
# 0                 135.2900              0.48             0.12            0.36
# 1                 187.4756              0.20             0.02            0.10
# 2                 180.6900              0.10             0.00            0.24
# 3                 181.8324              0.04             0.00            0.22
# 4                 196.4576              0.12             0.04            0.20
#
#    excl_per_comment  ellipsis_per_comment  E  ...  sentiment  is_Extrovert  \
# 0              0.06                  0.30  0  ...   0.166656             0
# 1              0.00                  0.38  1  ...   0.104312             1
# 2              0.08                  0.26  0  ...   0.145745             0
# 3              0.06                  0.52  0  ...   0.131263             0
# 4              0.02                  0.42  1  ...   0.075231             1
#
#    is_Sensing  is_Thinking  is_Judging  \
# 0           0            0           1
# 1           0            1           0
# 2           0            1           0
# 3           0            1           1
# 4           0            1           1
#
#                                                 text  Compound  Negative  \
# 0  moment sportscenter top ten play prank life ch...    0.9924     0.132
# 1  finding lack post alarming sex boring position...    0.9987     0.119
# 2  good one course say know blessing curse absolu...    0.9985     0.116
# 3  dear enjoyed conversation day esoteric gabbing...    0.9985     0.087
# 4  fired another silly misconception approaching ...    0.9930     0.186
#
#    Neutral  Positive
# 0    0.597     0.271
# 1    0.598     0.284
# 2    0.581     0.303
# 3    0.661     0.252
# 4    0.538     0.276
#
# [5 rows x 33 columns]

# %%
combined_df.to_csv(r'/Users/devinaamangal/Project-2/Final_ipynb/Resources/combined_df.csv', index = False)

# %%
cols = list(combined_df.columns.values)
cols
# Out:
# ['type',
#  'posts',
#  'words_per_comment',
#  'variance_of_word_counts',
#  'http_per_comment',
#  'img_per_comment',
#  'qm_per_comment',
#  'excl_per_comment',
#  'ellipsis_per_comment',
#  'E',
#  'I',
#  'S',
#  'N',
#  'F',
#  'T',
#  'P',
#  'J',
#  'nouns_per_comment',
#  'adjs_per_comment',
#  'verbs_per_comment',
#  'prepositions_per_comment',
#  'interjections_per_comment',
#  'determiners_per_comment',
#  'sentiment',
#  'is_Extrovert',
#  'is_Sensing',
#  'is_Thinking',
#  'is_Judging',
#  'text',
#  'Compound',
#  'Negative',
#  'Neutral',
#  'Positive']

# %% [markdown]
# # MACHINE LEARNING MODELS

# %%
# setting X to clean_posts, compound sentiment score, pos tags and various other counts
X = combined_df[
    [
        "text",
        "sentiment",
        "nouns_per_comment",
        "adjs_per_comment",
        "verbs_per_comment",
        "prepositions_per_comment",
        "interjections_per_comment",
        "determiners_per_comment",
        "words_per_comment",
        "variance_of_word_counts",
        "http_per_comment",
        "img_per_comment",
        "qm_per_comment",
        "excl_per_comment",
        "ellipsis_per_comment",
    ]
]

# setting y to four target classes -> is_Extrovert, is_Sensing, is_Thinking, is_Judging
y = combined_df.iloc[:, 24:28]

# ensuring that X and y row count matches
print(X.shape)
print(y.shape)
# Out:
# (8674, 15)
# (8674, 4)

# %%
additional_stopwords = [
    "hey","hello",'enfps','entps','infps','infjs','ne','enfjs','intps','ni','entjs','intjs','estps','isfps','istps',
    'isfjs','infps','infjs','se','enfps','si','intps','esfjs','intjs','entps','istjs','estps','ne','infps','infjs',
    'intps','intjs','entps','enfps','nt','ti','istjs','infjs','infps','intjs','ni','intps','entps','ne','istps','enfps',
    'isfjs','fi','fe','istjs','sx','ha','anime','type','perc','xd','hahaha','estjs','sp','lol','jawz','mbti','sj','nf','yo'
    'hsp','hitler'
]

# %%
counts_n_scores = [
#     "text",
    "sentiment",
    "nouns_per_comment",
    "adjs_per_comment",
    "verbs_per_comment",
    "prepositions_per_comment",
    "interjections_per_comment",
    "determiners_per_comment",
    "words_per_comment",
    "variance_of_word_counts",
    "http_per_comment",
    "img_per_comment",
    "qm_per_comment",
    "excl_per_comment",
    "ellipsis_per_comment"
]

# for selecting k best features from features other than words
best_k_features = make_pipeline(MinMaxScaler(), SelectKBest(f_classif, k=10))

# setting up preprocessing for TF-IDF vectorizer
preprocesser_tf = ColumnTransformer(
    transformers=[
        (
            "tfidf",
            TfidfVectorizer(min_df=25, max_df=0.85, stop_words=additional_stopwords),
            "text",
        ),
        ("selectbest", best_k_features, counts_n_scores),
    ],
    remainder="passthrough",
)

# setting up preprocessing for COUNT vectorizer
preprocesser_ct = ColumnTransformer(
    transformers=[
        (
            "ct_vect",
            CountVectorizer(min_df=25, max_df=0.85, stop_words=additional_stopwords),
            "text",
        ),
        ("selectbest", best_k_features, counts_n_scores),
    ],
    remainder="passthrough",
)

# %%
# setting up the personality dictionary for printing scores for each class
mbti_type = {
    "is_Extrovert": "Extrovert vs Introvert",
    "is_Sensing": "Sensing vs Intuition",
    "is_Thinking": "Thinking vs Feeling",
    "is_Judging": "Judging vs Perceiving",
}

# function to build the model for predicting each of the 4 target classes
def build_model(model, X, target, vectorizer_name):

    for col in target.columns:

        print(f"\n{mbti_type[col]}")
        target = y[col]

        X_train, X_test, y_train, y_test = train_test_split(
            X, target, test_size=0.2, random_state=42, stratify=target
        )

        # model training
        model.fit(X_train, y_train)

        # y_hat
        y_pred = model.predict(X_test)

        # y_probability
        y_proba = model.predict_proba(X_test)[:, 1]

        # precision recall score
        average_precision = average_precision_score(y_test, y_proba)

        # model evaluation
        print(
            f"Geometric Mean Score: {geometric_mean_score(y_test, y_pred, average='weighted'):.2f}"
        )
        print(f"ROC-AUC Score: {roc_auc_score(y_test, y_proba):.2f}")
        print(f"Average Precision-Recall Score: {average_precision:.2f}")
        print(classification_report_imbalanced(y_test, y_pred))

# %% [markdown]
# ### TF-IDF Logistic Regression

# %%
# %%time

tfidf_logistic_regression = imb_make_pipeline(
    preprocesser_tf, RandomUnderSampler(), LogisticRegressionCV()
)
build_model(tfidf_logistic_regression, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.69
# ROC-AUC Score: 0.76
# Average Precision-Recall Score: 0.50
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.89      0.67      0.72      0.76      0.69      0.48      1335
#           1       0.39      0.72      0.67      0.51      0.69      0.48       400
#
# avg / total       0.77      0.68      0.71      0.70      0.69      0.48      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.66
# ROC-AUC Score: 0.73
# Average Precision-Recall Score: 0.33
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.70      0.63      0.79      0.66      0.44      1496
#           1       0.25      0.63      0.70      0.36      0.66      0.43       239
#
# avg / total       0.83      0.69      0.64      0.73      0.66      0.44      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.79
# ROC-AUC Score: 0.87
# Average Precision-Recall Score: 0.84
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.84      0.76      0.83      0.80      0.79      0.62       939
#           1       0.74      0.83      0.76      0.78      0.79      0.63       796
#
# avg / total       0.80      0.79      0.80      0.79      0.79      0.63      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.64
# ROC-AUC Score: 0.68
# Average Precision-Recall Score: 0.58
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.73      0.63      0.65      0.68      0.64      0.41      1048
#           1       0.53      0.65      0.63      0.59      0.64      0.41       687
#
# avg / total       0.65      0.64      0.64      0.64      0.64      0.41      1735
#
# CPU times: user 2min 37s, sys: 2.08 s, total: 2min 39s
# Wall time: 1min 41s

# %% [markdown]
# ### Count Vectorized Logistic Regression

# %%
ct_logistic_regression = imb_make_pipeline(
    preprocesser_ct, RandomUnderSampler(), LogisticRegressionCV()
)
build_model(ct_logistic_regression, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.67
# ROC-AUC Score: 0.73
# Average Precision-Recall Score: 0.45
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.69      0.66      0.77      0.67      0.45      1335
#           1       0.39      0.66      0.69      0.49      0.67      0.45       400
#
# avg / total       0.76      0.68      0.66      0.70      0.67      0.45      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.67
# ROC-AUC Score: 0.71
# Average Precision-Recall Score: 0.29
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.93      0.64      0.69      0.76      0.67      0.45      1496
#           1       0.24      0.69      0.64      0.35      0.67      0.45       239
#
# avg / total       0.83      0.65      0.69      0.71      0.67      0.45      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.78
# ROC-AUC Score: 0.86
# Average Precision-Recall Score: 0.83
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.82      0.75      0.81      0.79      0.78      0.60       939
#           1       0.74      0.81      0.75      0.77      0.78      0.61       796
#
# avg / total       0.78      0.78      0.78      0.78      0.78      0.61      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.55
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.71      0.64      0.60      0.68      0.62      0.39      1048
#           1       0.53      0.60      0.64      0.56      0.62      0.39       687
#
# avg / total       0.64      0.63      0.62      0.63      0.62      0.39      1735

# %% [markdown]
# ### TF-IDF Logistic Lasso

# %%
# %%time
tfidf_logistic_regression_lasso = imb_make_pipeline(
    preprocesser_tf, RandomUnderSampler(), LogisticRegressionCV(penalty='l1', solver='saga' )
)
build_model(tfidf_logistic_regression_lasso, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.71
# Average Precision-Recall Score: 0.45
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.64      0.66      0.74      0.65      0.42      1335
#           1       0.36      0.66      0.64      0.46      0.65      0.42       400
#
# avg / total       0.75      0.65      0.66      0.67      0.65      0.42      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.63
# ROC-AUC Score: 0.70
# Average Precision-Recall Score: 0.30
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.91      0.66      0.61      0.77      0.63      0.40      1496
#           1       0.22      0.61      0.66      0.33      0.63      0.40       239
#
# avg / total       0.82      0.65      0.61      0.71      0.63      0.40      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.78
# ROC-AUC Score: 0.86
# Average Precision-Recall Score: 0.83
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.83      0.75      0.81      0.79      0.78      0.61       939
#           1       0.74      0.81      0.75      0.77      0.78      0.62       796
#
# avg / total       0.78      0.78      0.79      0.78      0.78      0.61      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.63
# ROC-AUC Score: 0.66
# Average Precision-Recall Score: 0.55
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.73      0.61      0.65      0.67      0.63      0.40      1048
#           1       0.53      0.65      0.61      0.58      0.63      0.40       687
#
# avg / total       0.65      0.63      0.64      0.63      0.63      0.40      1735
#
# CPU times: user 38min 11s, sys: 18.1 s, total: 38min 29s
# Wall time: 41min 43s

# %% [markdown]
# ### Count Vectorized Logistic Lasso

# %%
# %%time
ct_logistic_regression_lasso = imb_make_pipeline(
    preprocesser_ct, RandomUnderSampler(), LogisticRegressionCV(penalty='l1', solver='saga' )
)
build_model(ct_logistic_regression_lasso, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.71
# Average Precision-Recall Score: 0.44
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.66      0.63      0.75      0.65      0.42      1335
#           1       0.36      0.63      0.66      0.46      0.65      0.42       400
#
# avg / total       0.74      0.66      0.64      0.68      0.65      0.42      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.63
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.24
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.91      0.63      0.63      0.74      0.63      0.40      1496
#           1       0.21      0.63      0.63      0.32      0.63      0.40       239
#
# avg / total       0.82      0.63      0.63      0.69      0.63      0.40      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.77
# ROC-AUC Score: 0.85
# Average Precision-Recall Score: 0.82
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.81      0.75      0.79      0.78      0.77      0.59       939
#           1       0.73      0.79      0.75      0.76      0.77      0.60       796
#
# avg / total       0.77      0.77      0.77      0.77      0.77      0.60      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.61
# ROC-AUC Score: 0.66
# Average Precision-Recall Score: 0.56
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.71      0.60      0.63      0.65      0.61      0.38      1048
#           1       0.51      0.63      0.60      0.56      0.61      0.38       687
#
# avg / total       0.63      0.61      0.62      0.62      0.61      0.38      1735
#
# CPU times: user 38min 49s, sys: 6.22 s, total: 38min 55s
# Wall time: 39min 36s

# %% [markdown]
# ### TF-IDF Logistic Ridge

# %%
# %%time
tfidf_logistic_regression_ridge = imb_make_pipeline(
    preprocesser_tf, RandomUnderSampler(), LogisticRegressionCV(penalty='l2', solver='saga' )
)
build_model(tfidf_logistic_regression_ridge, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.67
# ROC-AUC Score: 0.74
# Average Precision-Recall Score: 0.49
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.67      0.66      0.76      0.67      0.44      1335
#           1       0.38      0.66      0.67      0.48      0.67      0.44       400
#
# avg / total       0.75      0.67      0.66      0.69      0.67      0.44      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.68
# ROC-AUC Score: 0.74
# Average Precision-Recall Score: 0.32
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.93      0.69      0.67      0.79      0.68      0.46      1496
#           1       0.26      0.67      0.69      0.37      0.68      0.46       239
#
# avg / total       0.84      0.69      0.68      0.73      0.68      0.46      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.79
# ROC-AUC Score: 0.87
# Average Precision-Recall Score: 0.84
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.84      0.75      0.83      0.79      0.79      0.62       939
#           1       0.74      0.83      0.75      0.78      0.79      0.63       796
#
# avg / total       0.79      0.79      0.79      0.79      0.79      0.62      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.68
# Average Precision-Recall Score: 0.56
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.71      0.64      0.61      0.68      0.62      0.39      1048
#           1       0.53      0.61      0.64      0.56      0.62      0.39       687
#
# avg / total       0.64      0.63      0.62      0.63      0.62      0.39      1735
#
# CPU times: user 4min 51s, sys: 3.89 s, total: 4min 55s
# Wall time: 5min 14s

# %% [markdown]
# ### Count Vectorized Logistic Ridge

# %%
# %%time
ct_logistic_regression_ridge = imb_make_pipeline(
    preprocesser_ct, RandomUnderSampler(), LogisticRegressionCV(penalty='l2', solver='saga' )
)
build_model(ct_logistic_regression_ridge, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.66
# ROC-AUC Score: 0.73
# Average Precision-Recall Score: 0.45
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.67      0.65      0.76      0.66      0.44      1335
#           1       0.37      0.65      0.67      0.47      0.66      0.44       400
#
# avg / total       0.75      0.67      0.66      0.69      0.66      0.44      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.70
# Average Precision-Recall Score: 0.28
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.68      0.62      0.78      0.65      0.42      1496
#           1       0.23      0.62      0.68      0.34      0.65      0.42       239
#
# avg / total       0.82      0.67      0.63      0.72      0.65      0.42      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.79
# ROC-AUC Score: 0.86
# Average Precision-Recall Score: 0.83
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.83      0.77      0.81      0.80      0.79      0.62       939
#           1       0.75      0.81      0.77      0.78      0.79      0.62       796
#
# avg / total       0.79      0.79      0.79      0.79      0.79      0.62      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.63
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.55
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.72      0.64      0.61      0.67      0.63      0.39      1048
#           1       0.53      0.61      0.64      0.57      0.63      0.39       687
#
# avg / total       0.64      0.63      0.62      0.63      0.63      0.39      1735
#
# CPU times: user 5min 34s, sys: 3.6 s, total: 5min 37s
# Wall time: 5min 58s

# %% [markdown]
# ### TF-IDF Support Vector Classifier

# %%
# %%time
tfidf_svc = imb_make_pipeline(
    preprocesser_tf, RandomUnderSampler(), DenseTransformer(), SVC(kernel='linear',probability=True)
)
build_model(tfidf_svc, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.67
# ROC-AUC Score: 0.74
# Average Precision-Recall Score: 0.48
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.66      0.68      0.75      0.67      0.45      1335
#           1       0.37      0.68      0.66      0.48      0.67      0.45       400
#
# avg / total       0.76      0.66      0.67      0.69      0.67      0.45      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.67
# ROC-AUC Score: 0.73
# Average Precision-Recall Score: 0.33
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.93      0.67      0.67      0.78      0.67      0.45      1496
#           1       0.24      0.67      0.67      0.36      0.67      0.45       239
#
# avg / total       0.83      0.67      0.67      0.72      0.67      0.45      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.79
# ROC-AUC Score: 0.87
# Average Precision-Recall Score: 0.84
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.85      0.74      0.84      0.79      0.79      0.62       939
#           1       0.73      0.84      0.74      0.78      0.79      0.63       796
#
# avg / total       0.79      0.79      0.80      0.79      0.79      0.62      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.56
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.72      0.62      0.63      0.67      0.62      0.39      1048
#           1       0.52      0.63      0.62      0.57      0.62      0.39       687
#
# avg / total       0.64      0.62      0.63      0.63      0.62      0.39      1735
#
# CPU times: user 1h 8min 20s, sys: 30.4 s, total: 1h 8min 50s
# Wall time: 39min 3s

# %% [markdown]
# ### Count Vectorized Support Vector Classifier

# %%
# %%time
ct_svc = imb_make_pipeline(
    preprocesser_ct, DenseTransformer(), RandomUnderSampler(), SVC(kernel='linear',probability=True)
)
build_model(ct_svc, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.40
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.85      0.61      0.64      0.71      0.62      0.39      1335
#           1       0.33      0.64      0.61      0.43      0.62      0.39       400
#
# avg / total       0.73      0.62      0.63      0.65      0.62      0.39      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.68
# Average Precision-Recall Score: 0.26
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.91      0.63      0.61      0.75      0.62      0.39      1496
#           1       0.21      0.61      0.63      0.31      0.62      0.39       239
#
# avg / total       0.81      0.63      0.61      0.69      0.62      0.39      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.74
# ROC-AUC Score: 0.81
# Average Precision-Recall Score: 0.77
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.78      0.73      0.76      0.76      0.74      0.55       939
#           1       0.71      0.76      0.73      0.73      0.74      0.56       796
#
# avg / total       0.75      0.74      0.75      0.74      0.74      0.55      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.58
# ROC-AUC Score: 0.62
# Average Precision-Recall Score: 0.50
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.68      0.58      0.59      0.63      0.58      0.34      1048
#           1       0.48      0.59      0.58      0.53      0.58      0.34       687
#
# avg / total       0.60      0.58      0.58      0.59      0.58      0.34      1735
#
# CPU times: user 1h 10min 8s, sys: 28.8 s, total: 1h 10min 36s
# Wall time: 39min 45s

# %% [markdown]
# ### TF-IDF Naive Bayes

# %%
# %%time
tfidf_nb = imb_make_pipeline(
    preprocesser_tf, DenseTransformer(), RandomUnderSampler(), MultinomialNB(),
)
build_model(tfidf_nb, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.68
# ROC-AUC Score: 0.75
# Average Precision-Recall Score: 0.48
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.89      0.61      0.75      0.72      0.68      0.45      1335
#           1       0.37      0.75      0.61      0.49      0.68      0.46       400
#
# avg / total       0.77      0.64      0.72      0.67      0.68      0.45      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.73
# Average Precision-Recall Score: 0.32
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.93      0.59      0.72      0.72      0.65      0.42      1496
#           1       0.22      0.72      0.59      0.34      0.65      0.43       239
#
# avg / total       0.83      0.61      0.71      0.67      0.65      0.42      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.78
# ROC-AUC Score: 0.85
# Average Precision-Recall Score: 0.80
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.79      0.81      0.75      0.80      0.78      0.61       939
#           1       0.77      0.75      0.81      0.76      0.78      0.60       796
#
# avg / total       0.78      0.78      0.78      0.78      0.78      0.61      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.62
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.56
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.72      0.59      0.65      0.65      0.62      0.38      1048
#           1       0.51      0.65      0.59      0.57      0.62      0.39       687
#
# avg / total       0.64      0.61      0.63      0.62      0.62      0.38      1735
#
# CPU times: user 27.5 s, sys: 2.33 s, total: 29.9 s
# Wall time: 28.3 s

# %% [markdown]
# ### Count Vectorized Naive Bayes

# %%
# %%time
ct_nb = imb_make_pipeline(
    preprocesser_ct, DenseTransformer(), RandomUnderSampler(), MultinomialNB(),
)
build_model(ct_nb, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.68
# ROC-AUC Score: 0.75
# Average Precision-Recall Score: 0.46
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.88      0.66      0.70      0.75      0.68      0.46      1335
#           1       0.38      0.70      0.66      0.49      0.68      0.46       400
#
# avg / total       0.77      0.67      0.69      0.69      0.68      0.46      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.68
# ROC-AUC Score: 0.74
# Average Precision-Recall Score: 0.32
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.93      0.70      0.66      0.80      0.68      0.46      1496
#           1       0.26      0.66      0.70      0.37      0.68      0.46       239
#
# avg / total       0.84      0.69      0.67      0.74      0.68      0.46      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.78
# ROC-AUC Score: 0.85
# Average Precision-Recall Score: 0.78
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.81      0.78      0.79      0.79      0.78      0.61       939
#           1       0.75      0.79      0.78      0.77      0.78      0.61       796
#
# avg / total       0.78      0.78      0.78      0.78      0.78      0.61      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.63
# ROC-AUC Score: 0.67
# Average Precision-Recall Score: 0.55
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.72      0.63      0.63      0.67      0.63      0.40      1048
#           1       0.53      0.63      0.63      0.57      0.63      0.40       687
#
# avg / total       0.64      0.63      0.63      0.63      0.63      0.40      1735
#
# CPU times: user 27.9 s, sys: 2.14 s, total: 30.1 s
# Wall time: 28.2 s

# %% [markdown]
# ### TF-IDF Random Forest

# %%
# %%time
tfidf_rf = imb_make_pipeline(
    preprocesser_tf, DenseTransformer(),
        RandomUnderSampler(),
        RandomForestClassifier(n_estimators=100, max_depth=10),
)
build_model(tfidf_rf, X, y, "tfidf")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.70
# Average Precision-Recall Score: 0.41
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.63      0.67      0.73      0.65      0.42      1335
#           1       0.35      0.67      0.63      0.46      0.65      0.42       400
#
# avg / total       0.74      0.64      0.66      0.66      0.65      0.42      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.61
# ROC-AUC Score: 0.65
# Average Precision-Recall Score: 0.24
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.91      0.61      0.61      0.73      0.61      0.37      1496
#           1       0.20      0.61      0.61      0.30      0.61      0.37       239
#
# avg / total       0.81      0.61      0.61      0.67      0.61      0.37      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.75
# ROC-AUC Score: 0.81
# Average Precision-Recall Score: 0.76
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.80      0.71      0.79      0.75      0.75      0.55       939
#           1       0.70      0.79      0.71      0.74      0.75      0.56       796
#
# avg / total       0.75      0.75      0.75      0.75      0.75      0.56      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.59
# ROC-AUC Score: 0.63
# Average Precision-Recall Score: 0.51
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.69      0.57      0.61      0.63      0.59      0.35      1048
#           1       0.48      0.61      0.57      0.54      0.59      0.35       687
#
# avg / total       0.61      0.59      0.59      0.59      0.59      0.35      1735
#
# CPU times: user 50.9 s, sys: 2.82 s, total: 53.7 s
# Wall time: 55.6 s

# %% [markdown]
# ### Count Vectorized Random Forest

# %%
# %%time
ct_rf = imb_make_pipeline(
    preprocesser_ct, RandomUnderSampler(), RandomForestClassifier(n_estimators=100, max_depth=10),
)
build_model(ct_rf, X, y, "ct_vect")
# Out:
# Extrovert vs Introvert
# Geometric Mean Score: 0.65
# ROC-AUC Score: 0.70
# Average Precision-Recall Score: 0.41
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.64      0.67      0.73      0.65      0.42      1335
#           1       0.36      0.67      0.64      0.46      0.65      0.43       400
#
# avg / total       0.75      0.64      0.66      0.67      0.65      0.42      1735
#
#
# Sensing vs Intuition
# Geometric Mean Score: 0.64
# ROC-AUC Score: 0.68
# Average Precision-Recall Score: 0.26
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.61      0.66      0.74      0.64      0.40      1496
#           1       0.21      0.66      0.61      0.32      0.64      0.41       239
#
# avg / total       0.82      0.62      0.65      0.68      0.64      0.40      1735
#
#
# Thinking vs Feeling
# Geometric Mean Score: 0.75
# ROC-AUC Score: 0.81
# Average Precision-Recall Score: 0.75
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.79      0.72      0.78      0.75      0.75      0.55       939
#           1       0.70      0.78      0.72      0.74      0.75      0.56       796
#
# avg / total       0.75      0.74      0.75      0.74      0.75      0.56      1735
#
#
# Judging vs Perceiving
# Geometric Mean Score: 0.56
# ROC-AUC Score: 0.60
# Average Precision-Recall Score: 0.47
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.66      0.59      0.53      0.62      0.56      0.31      1048
#           1       0.46      0.53      0.59      0.49      0.56      0.31       687
#
# avg / total       0.58      0.57      0.55      0.57      0.56      0.31      1735
#
# CPU times: user 29.5 s, sys: 696 ms, total: 30.2 s
# Wall time: 30.9 s

# %% [markdown]
# ### Final Model - Logistic Regression with TF-IDF Vectorization
#
# Selecting TF-IDF Logistic Regression as our final model as it returned the highest scores for all metrics - accuracy, precision, recall, roc-auc, avg_precision_recall as compared to other models.

# %%
# %%time

for col in y.columns:
    
    print(f"\n{mbti_type[col]}")

    target = y[col]

    tfidf_logistic_regression = imb_make_pipeline(
        preprocesser_tf,
        RandomUnderSampler(),
        LogisticRegressionCV()
    )
    
    # training the data on entire dataset
    tfidf_logistic_regression.fit(X, target)
    
    # feature importance   
    coef = tfidf_logistic_regression[-1].coef_[0]  
    word = tfidf_logistic_regression[0].named_transformers_["tfidf"].get_feature_names()
    word_list = list(zip(word, coef))         
    result = pd.DataFrame(word_list, columns=["word", "coef"]).set_index("word")    
    result = result.reindex(result.coef.abs().sort_values(ascending=False).index)[0:21]
    print(result)
    
    # plotting feature importance
    result["coef"] = result["coef"].apply(lambda x: abs(x))
    result.sort_values("coef", inplace=True)
    result.plot(kind="barh", color="#61BED6", title=mbti_type[col])
# Out:
# Extrovert vs Introvert
#                  coef
# word
# fun          4.249263
# guy          3.507846
# bored        3.181833
# quiet       -3.067069
# crazy        2.504902
# awesome      2.458007
# new          2.384094
# challenge    2.374397
# alot         2.355970
# family      -2.324148
# career       2.241374
# ego          2.236886
# boring       2.224990
# movement    -2.206746
# death       -2.158295
# besides     -2.139797
# let          2.101585
# instinctual  2.049173
# mind        -2.045842
# crack        2.008199
# nature      -1.999743
#
# Sensing vs Intuition
#                  coef
# word
# world       -3.710203
# rant         2.761084
# idea        -2.669318
# dream       -2.647837
# everyone    -2.493234
# car          2.483060
# personality  2.400213
# human       -2.114022
# stuff        2.048339
# rave         1.989424
# hope        -1.980434
# feel        -1.954076
# yet         -1.948105
# woman       -1.940297
# universe    -1.935378
# thanks       1.929466
# philosophy  -1.920039
# lonely      -1.910915
# light       -1.900063
# writing     -1.862644
# enneagram    1.826703
#
# Thinking vs Feeling
#                coef
# word
# feel      -6.635788
# female     5.189311
# love      -4.604467
# value     -3.758971
# feeling   -3.623055
# plan       3.496615
# boring     3.482002
# beautiful -3.474523
# emotion    3.448003
# world     -3.366500
# dream     -3.330790
# shy       -3.288615
# waste      3.249325
# knowledge  3.173259
# efficient  3.133916
# song      -3.091903
# others    -3.067764
# wish      -3.060458
# idealist  -3.040247
# joke       2.994653
# solve      2.889077
#
# Judging vs Perceiving
#                  coef
# word
# plan         4.879734
# intuition    3.755023
# fuck        -3.338381
# lazy        -3.095982
# cold         3.008753
# others       2.982238
# chaotic     -2.801929
# possibility -2.621129
# memory       2.606878
# parent      -2.602770
# rare         2.573284
# bored       -2.527943
# waste        2.514047
# help         2.494054
# idea        -2.437028
# sarcasm      2.436852
# hsp          2.435687
# empathy      2.424578
# rant         2.367397
# rave         2.338899
# live        -2.326354
# CPU times: user 3min 12s, sys: 1.99 s, total: 3min 14s
# Wall time: 1min 52s
